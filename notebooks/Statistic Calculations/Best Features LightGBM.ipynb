# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

# %%
#Create subplot

f, axes = plt.subplots(1, 3)
f.set_size_inches(20, 10)

# %%
dealservice_data = np.array([
                               ['Resolved_commit_date_dif', 235673.1645], ['Resolved_commit_date_dif', 239596.669], ['Resolved_commit_date_dif', 271972.736], ['Resolved_commit_date_dif', 237277.1223], ['Resolved_commit_date_dif', 254710.9437], ['Resolved_commit_date_dif', 258573.2029], ['Resolved_commit_date_dif', 248467.3152], ['Resolved_commit_date_dif', 237149.1549], ['Resolved_commit_date_dif', 268009.3443], ['Resolved_commit_date_dif', 241176.4876], ['Resolved_commit_date_dif', 255311.3569], ['Resolved_commit_date_dif', 244801.1133], ['Resolved_commit_date_dif', 243305.1604], ['Resolved_commit_date_dif', 239713.7173], ['Resolved_commit_date_dif', 266317.1032], ['Resolved_commit_date_dif', 242943.3239], ['Resolved_commit_date_dif', 262603.0291], ['Resolved_commit_date_dif', 249155.5701], ['Resolved_commit_date_dif', 232233.1943], ['Resolved_commit_date_dif', 242589.3287], ['Resolved_commit_date_dif', 246391.7167], ['Resolved_commit_date_dif', 235665.5825], ['Resolved_commit_date_dif', 232860.8808], ['Resolved_commit_date_dif', 238331.4313], ['Resolved_commit_date_dif', 265582.8946],
    ['Updated_commit_date_dif', 149979.2235], ['Updated_commit_date_dif', 155867.5346], ['Updated_commit_date_dif', 133422.7665], ['Updated_commit_date_dif', 150246.2699], ['Updated_commit_date_dif', 135328.4435], ['Updated_commit_date_dif', 137845.0866], ['Updated_commit_date_dif', 141093.1274], ['Updated_commit_date_dif', 155191.7907], ['Updated_commit_date_dif', 128538.738], ['Updated_commit_date_dif', 144017.2365], ['Updated_commit_date_dif', 122308.4617], ['Updated_commit_date_dif', 149222.5335], ['Updated_commit_date_dif', 146925.9641], ['Updated_commit_date_dif', 148005.3071], ['Updated_commit_date_dif', 130447.7155], ['Updated_commit_date_dif', 147695.1769], ['Updated_commit_date_dif', 105791.297], ['Updated_commit_date_dif', 147354.8559], ['Updated_commit_date_dif', 145559.094], ['Updated_commit_date_dif', 155972.7591], ['Updated_commit_date_dif', 144936.3667], ['Updated_commit_date_dif', 154736.8475], ['Updated_commit_date_dif', 147166.3762], ['Updated_commit_date_dif', 145030.3065], ['Updated_commit_date_dif', 131434.9689],
['vsm_logs_jira_as_query', 20713.71169], ['vsm_logs_jira_as_query', 23466.40185], ['vsm_logs_jira_as_query', 11241.41204], ['vsm_logs_jira_as_query', 22956.87085], ['vsm_logs_jira_as_query', 14180.15824], ['vsm_logs_jira_as_query', 15297.89962], ['vsm_logs_jira_as_query', 20454.27988], ['vsm_logs_jira_as_query', 23601.78686], ['vsm_logs_jira_as_query', 12700.87933], ['vsm_logs_jira_as_query', 23563.627], ['vsm_logs_jira_as_query', 15056.02717], ['vsm_logs_jira_as_query', 23716.38051], ['vsm_logs_jira_as_query', 22097.57454], ['vsm_logs_jira_as_query', 25068.7396], ['vsm_logs_jira_as_query', 17605.28732], ['vsm_logs_jira_as_query', 25156.23193], ['vsm_logs_jira_as_query', 16934.82525], ['vsm_logs_jira_as_query', 17202.35121], ['vsm_logs_jira_as_query', 24551.37577], ['vsm_logs_jira_as_query', 22111.48097], ['vsm_logs_jira_as_query', 19412.75666], ['vsm_logs_jira_as_query', 25023.56322], ['vsm_logs_jira_as_query', 26962.25565], ['vsm_logs_jira_as_query', 26206.10316], ['vsm_logs_jira_as_query', 14357.5602],
['Assignee_is_commiter', 17426.59606], ['Assignee_is_commiter', 11963.61499], ['Assignee_is_commiter', 17670.98817], ['Assignee_is_commiter', 16967.75983], ['Assignee_is_commiter', 18730.46369], ['Assignee_is_commiter', 16466.74547], ['Assignee_is_commiter', 19448.70608], ['Assignee_is_commiter', 11538.18355], ['Assignee_is_commiter', 16776.92309], ['Assignee_is_commiter', 13822.66507], ['Assignee_is_commiter', 20691.5808], ['Assignee_is_commiter', 13115.83802], ['Assignee_is_commiter', 16440.78656], ['Assignee_is_commiter', 15668.37051], ['Assignee_is_commiter', 16563.37785], ['Assignee_is_commiter', 13236.89033], ['Assignee_is_commiter', 20741.45021], ['Assignee_is_commiter', 17232.0052], ['Assignee_is_commiter', 13801.14896], ['Assignee_is_commiter', 12680.04258], ['Assignee_is_commiter', 15920.89157], ['Assignee_is_commiter', 13025.83451], ['Assignee_is_commiter', 13651.50286], ['Assignee_is_commiter', 12567.45405], ['Assignee_is_commiter', 21384.72322],
['vsm_svn_jira_jira_as_query', 9985.038243], ['vsm_svn_jira_jira_as_query', 9410.617904], ['vsm_svn_jira_jira_as_query', 8700.525522], ['vsm_svn_jira_jira_as_query', 10946.19884], ['vsm_svn_jira_jira_as_query', 10491.60684], ['vsm_svn_jira_jira_as_query', 9565.282498], ['vsm_svn_jira_jira_as_query', 10774.93149], ['vsm_svn_jira_jira_as_query', 11188.44808], ['vsm_svn_jira_jira_as_query', 8154.90458], ['vsm_svn_jira_jira_as_query', 9521.466292], ['vsm_svn_jira_jira_as_query', 7281.257379], ['vsm_svn_jira_jira_as_query', 10311.02945], ['vsm_svn_jira_jira_as_query', 12001.93155], ['vsm_svn_jira_jira_as_query', 13520.43306], ['vsm_svn_jira_jira_as_query', 5704.560075], ['vsm_svn_jira_jira_as_query', 9617.358505], ['vsm_svn_jira_jira_as_query', 9666.835319], ['vsm_svn_jira_jira_as_query', 10636.14699], ['vsm_svn_jira_jira_as_query', 10086.48834], ['vsm_svn_jira_jira_as_query', 11507.25307], ['vsm_svn_jira_jira_as_query', 8011.864902], ['vsm_svn_jira_jira_as_query', 12011.18], ['vsm_svn_jira_jira_as_query', 10150.20529], ['vsm_svn_jira_jira_as_query', 12224.09657], ['vsm_svn_jira_jira_as_query', 7009.426764],
    #['vsm_svn_summary_svn_as_query', 11760.30051], ['vsm_svn_summary_svn_as_query', 7690.994915], ['vsm_svn_summary_svn_as_query', 3059.000979], ['vsm_svn_summary_svn_as_query', 8014.309833], ['vsm_svn_summary_svn_as_query', 10776.37142], ['vsm_svn_summary_svn_as_query', 4463.957022], ['vsm_svn_summary_svn_as_query', 5123.288551], ['vsm_svn_summary_svn_as_query', 11942.98241], ['vsm_svn_summary_svn_as_query', 5382.110353], ['vsm_svn_summary_svn_as_query', 7018.803752], ['vsm_svn_summary_svn_as_query', 15101.78359], ['vsm_svn_summary_svn_as_query', 5521.363712], ['vsm_svn_summary_svn_as_query', 6105.720474], ['vsm_svn_summary_svn_as_query', 8959.59926], ['vsm_svn_summary_svn_as_query', 5977.199012], ['vsm_svn_summary_svn_as_query', 5885.158135], ['vsm_svn_summary_svn_as_query', 1686.642014], ['vsm_svn_summary_svn_as_query', 5613.820018], ['vsm_svn_summary_svn_as_query', 8221.092592], ['vsm_svn_summary_svn_as_query', 6863.01952], ['vsm_svn_summary_svn_as_query', 7165.258284], ['vsm_svn_summary_svn_as_query', 6587.71847], ['vsm_svn_summary_svn_as_query', 5312.67733], ['vsm_svn_summary_svn_as_query', 5988.166982], ['vsm_svn_summary_svn_as_query', 3815.653605]

    
                                   ])

dealservice_df = pd.DataFrame(data=dealservice_data, columns=["feature_name", "total_gain"])
dealservice_df["total_gain"] = pd.to_numeric(dealservice_df["total_gain"])
dealservice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   feature_name  125 non-null    object
#  1   total_gain    125 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.1+ KB

# %%
dealservice_plot = sns.boxplot(x="feature_name", y="total_gain", data=dealservice_df, ax=axes[0])
dealservice_plot.set_xticklabels(dealservice_plot.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Resolved_commit_date_dif'),
#  Text(1, 0, 'Updated_commit_date_dif'),
#  Text(2, 0, 'vsm_logs_jira_as_query'),
#  Text(3, 0, 'Assignee_is_commiter'),
#  Text(4, 0, 'vsm_svn_jira_jira_as_query')]

# %%
dataprocessing_data = np.array([
['Assignee_is_commiter', 49751.95], ['Assignee_is_commiter', 14357.39445], ['Assignee_is_commiter', 46751.02193], ['Assignee_is_commiter', 50118.63556], ['Assignee_is_commiter', 44079.72306], ['Assignee_is_commiter', 44968.45271], ['Assignee_is_commiter', 44207.47504], ['Assignee_is_commiter', 17850.38971], ['Assignee_is_commiter', 45426.17677], ['Assignee_is_commiter', 40544.01755], ['Assignee_is_commiter', 49015.67858], ['Assignee_is_commiter', 44499.88002], ['Assignee_is_commiter', 11480.38442], ['Assignee_is_commiter', 48309.77742], ['Assignee_is_commiter', 15708.11304], ['Assignee_is_commiter', 20254.72691], ['Assignee_is_commiter', 41303.36089], ['Assignee_is_commiter', 44922.59465], ['Assignee_is_commiter', 43484.06882], ['Assignee_is_commiter', 46908.11471], ['Assignee_is_commiter', 37279.6523], ['Assignee_is_commiter', 35329.68397], ['Assignee_is_commiter', 45187.32876], ['Assignee_is_commiter', 28982.66804], ['Assignee_is_commiter', 40231.6766],
['Updated_commit_date_dif', 20962.23749], ['Updated_commit_date_dif', 40135.17365], ['Updated_commit_date_dif', 25120.64116], ['Updated_commit_date_dif', 24153.00792], ['Updated_commit_date_dif', 21454.49591], ['Updated_commit_date_dif', 26893.33951], ['Updated_commit_date_dif', 30509.21535], ['Updated_commit_date_dif', 30870.7475], ['Updated_commit_date_dif', 18900.17481], ['Updated_commit_date_dif', 21223.11578], ['Updated_commit_date_dif', 24781.97778], ['Updated_commit_date_dif', 19893.26633], ['Updated_commit_date_dif', 42406.37471], ['Updated_commit_date_dif', 20776.28486], ['Updated_commit_date_dif', 30998.92348], ['Updated_commit_date_dif', 27392.45546], ['Updated_commit_date_dif', 26457.36645], ['Updated_commit_date_dif', 23210.49155], ['Updated_commit_date_dif', 34943.12714], ['Updated_commit_date_dif', 26810.41191], ['Updated_commit_date_dif', 26732.87328], ['Updated_commit_date_dif', 28153.1761], ['Updated_commit_date_dif', 22952.38397], ['Updated_commit_date_dif', 24833.70473], ['Updated_commit_date_dif', 24213.17216],
['Resolved_commit_date_dif', 26282.98926], ['Resolved_commit_date_dif', 10353.11456], ['Resolved_commit_date_dif', 21626.61448], ['Resolved_commit_date_dif', 21622.89879], ['Resolved_commit_date_dif', 26589.22263], ['Resolved_commit_date_dif', 22807.84476], ['Resolved_commit_date_dif', 20704.67883], ['Resolved_commit_date_dif', 17163.71338], ['Resolved_commit_date_dif', 30055.04478], ['Resolved_commit_date_dif', 26109.30739], ['Resolved_commit_date_dif', 23852.99443], ['Resolved_commit_date_dif', 25684.32007], ['Resolved_commit_date_dif', 11480.09558], ['Resolved_commit_date_dif', 30913.29019], ['Resolved_commit_date_dif', 21034.07118], ['Resolved_commit_date_dif', 18037.49935], ['Resolved_commit_date_dif', 23970.34285], ['Resolved_commit_date_dif', 27350.20626], ['Resolved_commit_date_dif', 13630.92748], ['Resolved_commit_date_dif', 18913.39939], ['Resolved_commit_date_dif', 21604.9669], ['Resolved_commit_date_dif', 21714.84399], ['Resolved_commit_date_dif', 26668.55553], ['Resolved_commit_date_dif', 21652.16114], ['Resolved_commit_date_dif', 21791.41094],
['vsm_comments_comments_as_query', 10142.14207], ['vsm_comments_comments_as_query', 18620.54224], ['vsm_comments_comments_as_query', 9614.205217], ['vsm_comments_comments_as_query', 8789.737801], ['vsm_comments_comments_as_query', 12801.28843], ['vsm_comments_comments_as_query', 10438.48835], ['vsm_comments_comments_as_query', 12354.56094], ['vsm_comments_comments_as_query', 10019.73868], ['vsm_comments_comments_as_query', 12718.62525], ['vsm_comments_comments_as_query', 13929.88455], ['vsm_comments_comments_as_query', 8272.680657], ['vsm_comments_comments_as_query', 15488.33099], ['vsm_comments_comments_as_query', 8343.86179], ['vsm_comments_comments_as_query', 5663.950102], ['vsm_comments_comments_as_query', 9319.500979], ['vsm_comments_comments_as_query', 17624.53737], ['vsm_comments_comments_as_query', 5784.217271], ['vsm_comments_comments_as_query', 14674.12608], ['vsm_comments_comments_as_query', 9030.690719], ['vsm_comments_comments_as_query', 9050.270875], ['vsm_comments_comments_as_query', 7424.708807], ['vsm_comments_comments_as_query', 16858.83231], ['vsm_comments_comments_as_query', 5957.881054], ['vsm_comments_comments_as_query', 12212.19241], ['vsm_comments_comments_as_query', 12269.60106],
['vsm_logs_jira_as_query', 8330.906965], ['vsm_logs_jira_as_query', 20710.01905], ['vsm_logs_jira_as_query', 6528.83722], ['vsm_logs_jira_as_query', 7222.138963], ['vsm_logs_jira_as_query', 6618.1912], ['vsm_logs_jira_as_query', 3207.973619], ['vsm_logs_jira_as_query', 5788.581967], ['vsm_logs_jira_as_query', 6531.301794], ['vsm_logs_jira_as_query', 3620.437033], ['vsm_logs_jira_as_query', 9086.48821], ['vsm_logs_jira_as_query', 6980.750966], ['vsm_logs_jira_as_query', 3258.330579], ['vsm_logs_jira_as_query', 29271.88786], ['vsm_logs_jira_as_query', 6550.882465], ['vsm_logs_jira_as_query', 23287.47313], ['vsm_logs_jira_as_query', 21128.87802], ['vsm_logs_jira_as_query', 11096.80037], ['vsm_logs_jira_as_query', 2762.348489], ['vsm_logs_jira_as_query', 10730.83792], ['vsm_logs_jira_as_query', 7065.457924], ['vsm_logs_jira_as_query', 16814.35173], ['vsm_logs_jira_as_query', 6701.149412], ['vsm_logs_jira_as_query', 7817.324533], ['vsm_logs_jira_as_query', 5444.816325], ['vsm_logs_jira_as_query', 9363.921699]
])

dataprocessing_df = pd.DataFrame(data=dataprocessing_data, columns=["feature_name", "total_gain"])
dataprocessing_df["total_gain"] = pd.to_numeric(dataprocessing_df["total_gain"])
dataprocessing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   feature_name  125 non-null    object
#  1   total_gain    125 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.1+ KB

# %%
dataprocessing_plot = sns.boxplot(x="feature_name", y="total_gain", data=dataprocessing_df, ax=axes[1])
dataprocessing_plot.set_xticklabels(dataprocessing_plot.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Assignee_is_commiter'),
#  Text(1, 0, 'Updated_commit_date_dif'),
#  Text(2, 0, 'Resolved_commit_date_dif'),
#  Text(3, 0, 'vsm_comments_comments_as_query'),
#  Text(4, 0, 'vsm_logs_jira_as_query')]

# %%
mxshop_data = np.array([
['Resolved_commit_date_dif', 53834.43067], ['Resolved_commit_date_dif', 37768.30305], ['Resolved_commit_date_dif', 105336.9627], ['Resolved_commit_date_dif', 49735.20831], ['Resolved_commit_date_dif', 130374.2917], ['Resolved_commit_date_dif', 108953.3736], ['Resolved_commit_date_dif', 111724.8998], ['Resolved_commit_date_dif', 124774.1626], ['Resolved_commit_date_dif', 2312.082559], ['Resolved_commit_date_dif', 3998.268681], ['Resolved_commit_date_dif', 139886.4899], ['Resolved_commit_date_dif', 31412.73932], ['Resolved_commit_date_dif', 121404.7561], ['Resolved_commit_date_dif', 33306.6903], ['Resolved_commit_date_dif', 70909.95381], ['Resolved_commit_date_dif', 108218.5051], ['Resolved_commit_date_dif', 10765.97253], ['Resolved_commit_date_dif', 9917.015743], ['Resolved_commit_date_dif', 98238.54817], ['Resolved_commit_date_dif', 107063.0812], ['Resolved_commit_date_dif', 38836.30995], ['Resolved_commit_date_dif', 68124.43583], ['Resolved_commit_date_dif', 6426.541042], ['Resolved_commit_date_dif', 130128.6613], ['Resolved_commit_date_dif', 124711.6895],
['vsm_summary_logs_summary_as_query', 64564.12134], ['vsm_summary_logs_summary_as_query', 72161.05598], ['vsm_summary_logs_summary_as_query', 17322.52492], ['vsm_summary_logs_summary_as_query', 44812.13834], ['vsm_summary_logs_summary_as_query', 16900.17951], ['vsm_summary_logs_summary_as_query', 25608.82979], ['vsm_summary_logs_summary_as_query', 13215.08447], ['vsm_summary_logs_summary_as_query', 20488.86278], ['vsm_summary_logs_summary_as_query', 97002.88101], ['vsm_summary_logs_summary_as_query', 98979.59971], ['vsm_summary_logs_summary_as_query', 8527.490898], ['vsm_summary_logs_summary_as_query', 61829.03315], ['vsm_summary_logs_summary_as_query', 16080.8189], ['vsm_summary_logs_summary_as_query', 82213.97493], ['vsm_summary_logs_summary_as_query', 64090.48285], ['vsm_summary_logs_summary_as_query', 20643.5886], ['vsm_summary_logs_summary_as_query', 81636.04768], ['vsm_summary_logs_summary_as_query', 85827.57962], ['vsm_summary_logs_summary_as_query', 21507.75255], ['vsm_summary_logs_summary_as_query', 4577.335811], ['vsm_summary_logs_summary_as_query', 57735.81035], ['vsm_summary_logs_summary_as_query', 50749.69771], ['vsm_summary_logs_summary_as_query', 92008.14096], ['vsm_summary_logs_summary_as_query', 14392.59742], ['vsm_summary_logs_summary_as_query', 21235.20714],
['Creation_commit_date_dif', 2689.72953], ['Creation_commit_date_dif', 2963.61116], ['Creation_commit_date_dif', 4449.941693], ['Creation_commit_date_dif', 9654.326227], ['Creation_commit_date_dif', 4028.585045], ['Creation_commit_date_dif', 2909.812767], ['Creation_commit_date_dif', 3410.634177], ['Creation_commit_date_dif', 1778.270854], ['Creation_commit_date_dif', 17276.28284], ['Creation_commit_date_dif', 16026.72852], ['Creation_commit_date_dif', 5659.045943], ['Creation_commit_date_dif', 16283.6652], ['Creation_commit_date_dif', 2928.201091], ['Creation_commit_date_dif', 2895.377811], ['Creation_commit_date_dif', 2636.353342], ['Creation_commit_date_dif', 5653.158953], ['Creation_commit_date_dif', 22966.71769], ['Creation_commit_date_dif', 22851.11947], ['Creation_commit_date_dif', 9274.356309], ['Creation_commit_date_dif', 5601.191125], ['Creation_commit_date_dif', 17965.89427], ['Creation_commit_date_dif', 11094.4601], ['Creation_commit_date_dif', 9905.573903], ['Creation_commit_date_dif', 996.4615485], ['Creation_commit_date_dif', 4244.758467],
['Updated_commit_date_dif', 10829.46462], ['Updated_commit_date_dif', 19042.49023], ['Updated_commit_date_dif', 1541.715696], ['Updated_commit_date_dif', 18563.32795], ['Updated_commit_date_dif', 594.1826161], ['Updated_commit_date_dif', 746.1089008], ['Updated_commit_date_dif', 1051.383048], ['Updated_commit_date_dif', 689.4355457], ['Updated_commit_date_dif', 17010.17557], ['Updated_commit_date_dif', 6401.587414], ['Updated_commit_date_dif', 512.7184641], ['Updated_commit_date_dif', 10585.93022], ['Updated_commit_date_dif', 1647.658649], ['Updated_commit_date_dif', 20912.04822], ['Updated_commit_date_dif', 2322.915333], ['Updated_commit_date_dif', 11087.33801], ['Updated_commit_date_dif', 16262.37921], ['Updated_commit_date_dif', 11745.85991], ['Updated_commit_date_dif', 5630.102752], ['Updated_commit_date_dif', 1174.214925], ['Updated_commit_date_dif', 8158.882647], ['Updated_commit_date_dif', 4222.357121], ['Updated_commit_date_dif', 12410.14684], ['Updated_commit_date_dif', 520.2068957], ['Updated_commit_date_dif', 2160.804671],
['JiraSummariesAsQuery_QueryScope', 12819.76926], ['JiraSummariesAsQuery_QueryScope', 11950.96174], ['JiraSummariesAsQuery_QueryScope', 2028.608512], ['JiraSummariesAsQuery_QueryScope', 6362.139697], ['JiraSummariesAsQuery_QueryScope', 3669.979834], ['JiraSummariesAsQuery_QueryScope', 4549.925508], ['JiraSummariesAsQuery_QueryScope', 3319.03675], ['JiraSummariesAsQuery_QueryScope', 4672.660108], ['JiraSummariesAsQuery_QueryScope', 5182.696664], ['JiraSummariesAsQuery_QueryScope', 11231.88229], ['JiraSummariesAsQuery_QueryScope', 1575.464731], ['JiraSummariesAsQuery_QueryScope', 7103.839331], ['JiraSummariesAsQuery_QueryScope', 2349.687512], ['JiraSummariesAsQuery_QueryScope', 9939.159266], ['JiraSummariesAsQuery_QueryScope', 10550.37664], ['JiraSummariesAsQuery_QueryScope', 3600.217306], ['JiraSummariesAsQuery_QueryScope', 10389.76802], ['JiraSummariesAsQuery_QueryScope', 9581.072535], ['JiraSummariesAsQuery_QueryScope', 7683.774156], ['JiraSummariesAsQuery_QueryScope', 3411.799594], ['JiraSummariesAsQuery_QueryScope', 10898.99727], ['JiraSummariesAsQuery_QueryScope', 9794.850699], ['JiraSummariesAsQuery_QueryScope', 9418.96807], ['JiraSummariesAsQuery_QueryScope', 3003.310498], ['JiraSummariesAsQuery_QueryScope', 4125.544296]
])

mxshop_df = pd.DataFrame(data=mxshop_data, columns=["feature_name", "total_gain"])
mxshop_df["total_gain"] = pd.to_numeric(mxshop_df["total_gain"])
mxshop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   feature_name  125 non-null    object
#  1   total_gain    125 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.1+ KB

# %%
dataprocessing_plot = sns.boxplot(x="feature_name", y="total_gain", data=mxshop_df, ax=axes[2])
dataprocessing_plot.set_xticklabels(dataprocessing_plot.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Resolved_commit_date_dif'),
#  Text(1, 0, 'vsm_summary_logs_summary_as_query'),
#  Text(2, 0, 'Creation_commit_date_dif'),
#  Text(3, 0, 'Updated_commit_date_dif'),
#  Text(4, 0, 'JiraSummariesAsQuery_QueryScope')]

# %%
f
