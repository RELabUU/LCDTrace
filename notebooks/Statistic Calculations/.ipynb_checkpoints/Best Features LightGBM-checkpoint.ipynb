# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

# %%
#Create subplot

f, axes = plt.subplots(1, 3)
f.set_size_inches(20, 10)

# %%
dealservice_data = np.array([
                               235673.1645	239596.669	271972.736	237277.1223	254710.9437	258573.2029	248467.3152	237149.1549	268009.3443	241176.4876	255311.3569	244801.1133	243305.1604	239713.7173	266317.1032	242943.3239	262603.0291	249155.5701	232233.1943	242589.3287	246391.7167	235665.5825	232860.8808	238331.4313	265582.8946
    149979.2235	155867.5346	133422.7665	150246.2699	135328.4435	137845.0866	141093.1274	155191.7907	128538.738	144017.2365	122308.4617	149222.5335	146925.9641	148005.3071	130447.7155	147695.1769	105791.297	147354.8559	145559.094	155972.7591	144936.3667	154736.8475	147166.3762	145030.3065	131434.9689
20713.71169	23466.40185	11241.41204	22956.87085	14180.15824	15297.89962	20454.27988	23601.78686	12700.87933	23563.627	15056.02717	23716.38051	22097.57454	25068.7396	17605.28732	25156.23193	16934.82525	17202.35121	24551.37577	22111.48097	19412.75666	25023.56322	26962.25565	26206.10316	14357.5602
17426.59606	11963.61499	17670.98817	16967.75983	18730.46369	16466.74547	19448.70608	11538.18355	16776.92309	13822.66507	20691.5808	13115.83802	16440.78656	15668.37051	16563.37785	13236.89033	20741.45021	17232.0052	13801.14896	12680.04258	15920.89157	13025.83451	13651.50286	12567.45405	21384.72322
9985.038243	9410.617904	8700.525522	10946.19884	10491.60684	9565.282498	10774.93149	11188.44808	8154.90458	9521.466292	7281.257379	10311.02945	12001.93155	13520.43306	5704.560075	9617.358505	9666.835319	10636.14699	10086.48834	11507.25307	8011.864902	12011.18	10150.20529	12224.09657	7009.426764

                                   ])

dealservice_df = pd.DataFrame(data=dealservice_data, columns=["feature_name", "total_gain"])
dealservice_df["total_gain"] = pd.to_numeric(dealservice_df["total_gain"])
dealservice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   feature_name  125 non-null    object
#  1   total_gain    125 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.1+ KB

# %%
dealservice_plot = sns.boxplot(x="feature_name", y="total_gain", data=dealservice_df, ax=axes[0])
dealservice_plot.set_xticklabels(dealservice_plot.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Updated_commit_date_dif'),
#  Text(1, 0, 'Resolved_commit_date_dif'),
#  Text(2, 0, 'Assignee_is_commiter'),
#  Text(3, 0, 'vsm_svn_jira_svn_as_query'),
#  Text(4, 0, 'total_term_count_jira')]

# %%
dataprocessing_data = np.array([



])

dataprocessing_df = pd.DataFrame(data=dataprocessing_data, columns=["feature_name", "total_gain"])
dataprocessing_df["total_gain"] = pd.to_numeric(dataprocessing_df["total_gain"])
dataprocessing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   feature_name  125 non-null    object
#  1   total_gain    125 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.1+ KB

# %%
dataprocessing_plot = sns.boxplot(x="feature_name", y="total_gain", data=dataprocessing_df, ax=axes[1])
dataprocessing_plot.set_xticklabels(dataprocessing_plot.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'JiraSummariesAsQuery_maxEntropy'),
#  Text(1, 0, 'vsm_logs_jira_as_query'),
#  Text(2, 0, 'Resolved_commit_date_dif'),
#  Text(3, 0, 'Assignee_is_commiter'),
#  Text(4, 0, 'Updated_commit_date_dif')]

# %%
mxshop_data = np.array([

])

mxshop_df = pd.DataFrame(data=mxshop_data, columns=["feature_name", "total_gain"])
mxshop_df["total_gain"] = pd.to_numeric(mxshop_df["total_gain"])
mxshop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   feature_name  125 non-null    object
#  1   total_gain    125 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.1+ KB

# %%
dataprocessing_plot = sns.boxplot(x="feature_name", y="total_gain", data=mxshop_df, ax=axes[2])
dataprocessing_plot.set_xticklabels(dataprocessing_plot.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'JiraSummariesAsQuery_maxICTF'),
#  Text(1, 0, 'JiraSummariesAsQuery_avgICTF'),
#  Text(2, 0, 'JiraDescriptionsAsQuery_avgEntropy'),
#  Text(3, 0, 'vsm_svn_jira_jira_as_query'),
#  Text(4, 0, 'vsm_svn_description_description_as_query')]

# %%
f
